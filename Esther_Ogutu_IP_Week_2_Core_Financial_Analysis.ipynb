# %% [markdown]
# <a href="https://colab.research.google.com/github/EstherOgutu/Esther_projects/blob/master/Esther_Ogutu_IP_Week_2_Core_Financial_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## FINANCIAL ANALYSIS

# %% [markdown]
# #1. Defining the Question

# %% [markdown]
# ###**a) Specifying the Data Analytic Question**
#
# Idenfying how we can predict which individuals that are most likely to have or use a bank account Kenya, Rwanda, Tanzania, and Uganda.

# %% [markdown]
# ###**b) Defining the Metric of Success**
#
# Being able to predict the individuals that are most likely to have or use a bank account Kenya, Rwanda, Tanzania, and Uganda. The metric of success in this case is 80%.

# %% [markdown]
# ###**c) Understanding the Context**
# This data is from a financial Sector, such as a bank, where a prediction of how many people have a bank account in kenya, Uganda, Tanzania, and Rwanda is being analayzed. Over the years, the use of banks has risen and many people are using Banks to save. As such, we want to carry out a predictive analysis to see what percentage of people have bank accounts.

# %% [markdown]
# ###**d) Recording the Experimental Design**
#
# For this Analsis, I will clean the Dataset first before Analysis. For the cleaning part, I will check for outliers, anomalies, missing values, renaming some columns, along with their values, checking for duplicates and changing the column names into lowercase for uniformity and stripping off whitespaces and dashes.

# %% [markdown]
# ###**e) Data Relevance**
# This data is relevant to the financial institution because it gives a business understanding of how many people actually use the banks to save. From the data, one can be able to see the characteristics of the people who use banks, and those who do not. It can also give an insight og meaningful ways to reach those who do not use banks.

# %% [markdown]
# #2. Reading the Data

# %%
#Importing the Libraries that we will use

# Importing Numpy
import numpy as np

# Importing Pandas
import pandas as pd

# Importing Matplotlib
import matplotlib.pyplot as plt

# Importing Seaborn
import seaborn as sns

# Loading the Data from the source
financial_df=pd.read_csv('Financial Dataset 1.csv')

# %% [markdown]
# #3. Checking the Data

# %%
# Determining the no. of records in our dataset
#
financial_df.shape
# Out:
# (23524, 13)

# %%
# Previewing the top of our Dataset
#
financial_df.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Previewing the bottom of our Dataset
#
financial_df.tail()
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 23519               Yes             4.0            48.0               Female
# 23520               Yes             2.0            27.0               Female
# 23521               Yes             5.0            27.0               Female
# 23522               Yes             7.0            30.0               Female
# 23523               Yes            10.0            20.0                 Male
#
#       The relathip with head        marital_status  Level of Educuation  \
# ...

# %%
# Checking all the columns have the appropriate Datatype
#
financial_df.dtypes
# Out:
# country                    object
# year                        int64
# uniqueid                   object
# Has a Bank account         object
# Type of Location           object
# Cell Phone Access          object
# household_size            float64
# Respondent Age            float64
# gender_of_respondent       object
# The relathip with head     object
# marital_status             object
# Level of Educuation        object
# Type of Job                object
# dtype: object

# %%
# Checking the information about the Dataset
#
financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has a Bank account      23488 non-null  object
#  4   Type of Location        23509 non-null  object
#  5   Cell Phone Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The relathip with head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level of Educuation     23495 non-null  object
#  12  Type of Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
# Getting the statatistical description of the dataset for our numerical values
#
financial_df.describe()
# Out:
#                year  household_size  Respondent Age
# count  23524.000000    23496.000000    23490.000000
# mean    2016.979000        3.681818       38.804300
# std        0.899669        2.279933       16.519996
# min     2016.000000        0.000000       16.000000
# 25%     2016.000000        2.000000       26.000000
# 50%     2017.000000        3.000000       35.000000
# 75%     2018.000000        5.000000       49.000000
# max     2056.000000       21.000000      100.000000

# %% [markdown]
# #4. External Data Source Validation

# %% [markdown]
# #5. Tiding the Dataset

# %%
# Checking for Outliers
#
Q1 =financial_df.quantile(0.25)

# Calculating the Third Quartile
Q3 = financial_df.quantile(0.75)

# Calculating the Quartile Range
IQR = Q3 - Q1

print((financial_df < (Q1 - 1.5 * IQR)) | (financial_df > (Q3 + 1.5 * IQR)))
print('-------------------------------------------------------------------------------')

#Displaying the number of outliers in the fields where the exist
print(IQR)
# Out:
#        Cell Phone Access  Has a Bank account  Level of Educuation  \
# 0                  False               False                False
# 1                  False               False                False
# 2                  False               False                False
# 3                  False               False                False
# 4                  False               False                False
# ...                  ...                 ...                  ...
# 23519              False               False                False
# 23520              False               False                False
# 23521              False               False                False
# 23522              False               False                False
# 23523              False               False                False
#
#        Respondent Age  The relathip with head  Type of Job  Type of Location  \
# 0               False                   False        False             False
# ...

# %%
# Using a boxplot to visualize the outliers in the three columns
fig, ((ax1, ax2, ax3)) = plt.subplots(3, figsize=(10, 10))
fig.suptitle('Boxplots')
sns.boxplot(financial_df['year'], ax=ax1)
sns.boxplot(financial_df['household_size'], ax=ax2)
sns.boxplot(financial_df['Respondent Age'], ax=ax3)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Removing the Outliers
#
financial_df = financial_df[~((financial_df < (Q1 - 1.5 * IQR)) | (financial_df > (Q3 + 1.5 * IQR))).any(axis=1)]
financial_df.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   This is separate from the ipykernel package so we can avoid doing imports until
# (22903, 13)

# %% [markdown]
# Our original shape with the outliers, the data had a shape of (23525,13). Our new dataframe after removing the outliers has a shape of (22903,13). The difference is 622, which is not significant enough interfere with our Analysis.

# %%
# Find the total Missing Data in each column
#
financial_df.isnull().sum()
# Out:
# country                   14
# year                       0
# uniqueid                   0
# Has a Bank account        36
# Type of Location          15
# Cell Phone Access         11
# household_size            27
# Respondent Age            33
# gender_of_respondent      33
# The relathip with head     4
# marital_status            31
# Level of Educuation       29
# Type of Job               30
# dtype: int64

# %%
financial_df=financial_df.dropna()
financial_df.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
financial_df.shape
# Out:
# (22725, 13)

# %% [markdown]
# Our shape initially before removing the missing data was (22903,13). Our new dataframe after removing the outliers has a shape of (22725,13). The difference is 178, which is not significant enough interfere with our Analysis.

# %%
# We are removing the prefix "uniqueid_" in our uniqueid column to avoid alot of redandancy 
#
financial_df['uniqueid'] = financial_df['uniqueid'].str.lstrip('uniqueid_')
financial_df.head()
# Out:
#   country  year uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018        1                Yes            Rural
# 1   Kenya  2018        2                 No            Rural
# 2   Kenya  2018        3                Yes            Urban
# 3   Kenya  2018        4                 No            Rural
# 4   Kenya  2018        5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
#To ensure uniformity,we will change the column names to lower case, stripping of the whitespaces,removing periods, 
#this ensures good readerbility plus every possible naming issue is covered.

financial_df.columns = financial_df.columns.str.lower().str.strip().str.replace(' ', '_').str.replace('.', '')
financial_df.info()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22725 entries, 0 to 23522
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 22725 non-null  object
#  1   year                    22725 non-null  int64
#  2   uniqueid                22725 non-null  object
#  3   has_a_bank_account      22725 non-null  object
#  4   type_of_location        22725 non-null  object
#  5   cell_phone_access       22725 non-null  object
#  6   household_size          22725 non-null  float64
#  7   respondent_age          22725 non-null  float64
# ...

# %%
# Changing the datatype of household_size from float to interger
#
financial_df = financial_df.astype({"household_size": int}, errors='raise') 
financial_df.dtypes
# Out:
# country                    object
# year                        int64
# uniqueid                   object
# has_a_bank_account         object
# type_of_location           object
# cell_phone_access          object
# household_size              int64
# respondent_age            float64
# gender_of_respondent       object
# the_relathip_with_head     object
# marital_status             object
# level_of_educuation        object
# type_of_job                object
# dtype: object

# %%
# Checking for any duplicates in the dataset
#
financial_df.duplicated().sum()
# Out:
# 0

# %%
# Exporting our cleaned dataset
#
financial_df.to_csv("financial_df.csv", index=False)

# %%
# Lets read our dataset from our CSV file and create a dataframe that we will use
#
financial_df=pd.read_csv('financial_df.csv')

# %%
# Previewing the first 10 entries in our dataframe
financial_df.head()
# Out:
#   country  year  uniqueid has_a_bank_account type_of_location  \
# 0   Kenya  2018         1                Yes            Rural
# 1   Kenya  2018         2                 No            Rural
# 2   Kenya  2018         3                Yes            Urban
# 3   Kenya  2018         4                 No            Rural
# 4   Kenya  2018         5                 No            Urban
#
#   cell_phone_access  household_size  respondent_age gender_of_respondent  \
# 0               Yes               3            24.0               Female
# 1                No               5            70.0               Female
# 2               Yes               5            26.0                 Male
# 3               Yes               5            34.0               Female
# 4                No               8            26.0                 Male
#
#   the_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Previewing the first 10 entries in our dataframe
financial_df.tail()
# Out:
#       country  year  uniqueid has_a_bank_account type_of_location  \
# 22720  Uganda  2018      2102                 No            Rural
# 22721  Uganda  2018      2113                 No            Rural
# 22722  Uganda  2018      2114                 No            Rural
# 22723  Uganda  2018      2115                 No            Rural
# 22724  Uganda  2018      2116                 No            Urban
#
#       cell_phone_access  household_size  respondent_age gender_of_respondent  \
# 22720                No               2            57.0               Female
# 22721               Yes               4            48.0               Female
# 22722               Yes               2            27.0               Female
# 22723               Yes               5            27.0               Female
# 22724               Yes               7            30.0               Female
#
#       the_relathip_with_head        marital_status  level_of_educuation  \
# ...

# %% [markdown]
# #6. Univariate Analysis

# %% [markdown]
# #### Continous Variable Analysis

# %%
# 1.Standard Deviation
financial_df['respondent_age'].std()
# Out:
# 15.806141256107674

# %%
# 2.Variance
financial_df['respondent_age'].var()
# Out:
# 249.83410140802906

# %%
# 3.Range
financial_df['respondent_age'].min()
financial_df['respondent_age'].max()

range=financial_df['respondent_age'].max()-financial_df['respondent_age'].min()
range
# Out:
# 67.0

# %%
# 4.Quantiles
financial_df['respondent_age'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    26.0
# 0.50    35.0
# 0.75    48.0
# Name: respondent_age, dtype: float64

# %%
# 5.Skewness
financial_df['respondent_age'].skew()
# Out:
# 0.7402138281724044

# %%
# 6.Kurtosis

financial_df['respondent_age'].kurt()
# Out:
# -0.23749387799691757

# %%
financial_df['respondent_age'].describe()
# Out:
# count    22725.000000
# mean        38.347987
# std         15.806141
# min         16.000000
# 25%         26.000000
# 50%         35.000000
# 75%         48.000000
# max         83.000000
# Name: respondent_age, dtype: float64

# %% [markdown]
# #### Categorical Data

# %%
# Getting a description of the statistics of numerical values
financial_df.describe()
# Out:
#                year      uniqueid  household_size  respondent_age
# count  22725.000000  22725.000000    22725.000000    22725.000000
# mean    2016.968185   3436.911155        3.579846       38.347987
# std        0.846366   2253.786144        2.080542       15.806141
# min     2016.000000      1.000000        0.000000       16.000000
# 25%     2016.000000   1478.000000        2.000000       26.000000
# 50%     2017.000000   3233.000000        3.000000       35.000000
# 75%     2018.000000   5185.000000        5.000000       48.000000
# max     2018.000000   8759.000000        9.000000       83.000000

# %%
# We are Analysing the Target Variable "Has bank account"
financial_df['has_a_bank_account'].value_counts()
# Out:
# No     19490
# Yes     3235
# Name: has_a_bank_account, dtype: int64

# %%
# Let's calculate the percentage of the people with bank accounts
(financial_df['has_a_bank_account'].value_counts()/financial_df.shape[0]*100).round(2)
# Out:
# No     85.76
# Yes    14.24
# Name: has_a_bank_account, dtype: float64

# %%
# Plotting a graph of those people with bank accounts and those without bank accounts
# with their respective percentages
sns.set(style="whitegrid")
plt.figure(figsize=(4,4))
total = float(len(financial_df))
ax = sns.countplot(data=financial_df,x='has_a_bank_account')
plt.title('Percentages provided for each scenario', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()

# %% [markdown]
# A count plot can be thought of as a histogram across a categorical. In our case, this count plot can be viewed as a histogram for our "Has a bank account" categorical data.
# The results of the histogram show majority of the people do not have bank accounts (85.5%), compared to the 14.2% with bank accounts.

# %%
# Checking the information of our dataset
financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22725 entries, 0 to 22724
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 22725 non-null  object
#  1   year                    22725 non-null  int64
#  2   uniqueid                22725 non-null  int64
#  3   has_a_bank_account      22725 non-null  object
#  4   type_of_location        22725 non-null  object
#  5   cell_phone_access       22725 non-null  object
#  6   household_size          22725 non-null  int64
#  7   respondent_age          22725 non-null  float64
#  8   gender_of_respondent    22725 non-null  object
#  9   the_relathip_with_head  22725 non-null  object
#  10  marital_status          22725 non-null  object
#  11  level_of_educuation     22725 non-null  object
#  12  type_of_job             22725 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 2.3+ MB

# %%
# Using bar graphs to cary out Analysis of the different variables and how they relate to each other
fig,axes=plt.subplots(4,3, figsize=(30,30))
sns.countplot('country', data=financial_df, ax=axes[0,0])
sns.countplot('has_a_bank_account', data=financial_df, ax=axes[0,1])
sns.countplot('type_of_location', data=financial_df, ax=axes[0,2])
sns.countplot('cell_phone_access', data=financial_df, ax=axes[1,0])
sns.countplot('gender_of_respondent', data=financial_df, ax=axes[1,1])
sns.countplot('the_relathip_with_head', data=financial_df, ax=axes[1,2])
sns.countplot('marital_status', data=financial_df, ax=axes[2,0])
sns.countplot('level_of_educuation', data=financial_df, ax=axes[2,1])
sns.distplot(financial_df['year'].dropna(), kde=True, ax=axes[2,2])
sns.distplot(financial_df['uniqueid'], kde=True, ax=axes[3,0])
sns.distplot(financial_df['household_size'].dropna(), kde=True, ax=axes[3,1])
sns.distplot(financial_df['respondent_age'].dropna(), kde=True, ax=axes[3,2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# From the Histogram, the following can be deduced:
# 1. Rwanda has the highest population of people with bank accounts.
# 2. More people in the rural areas have bank accounts, compared to those living in the urban areas.
# 3. In the entire population, more people have access to cell phones.
# 4. More Female have bank accounts compared to their male couterparts.
# 5. Most people lie in the age bracket of 20-40 years.

# %% [markdown]
# #7. Bivariate Analysis

# %% [markdown]
# Categorical and Continous

# %%
# Renaming the gender_of_respondent column to sex
financial_df=financial_df.rename(columns={'gender_of_respondent':'sex'})

# %%
# Checking the information of our dataset
financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22725 entries, 0 to 22724
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 22725 non-null  object
#  1   year                    22725 non-null  int64
#  2   uniqueid                22725 non-null  int64
#  3   has_a_bank_account      22725 non-null  object
#  4   type_of_location        22725 non-null  object
#  5   cell_phone_access       22725 non-null  object
#  6   household_size          22725 non-null  int64
#  7   respondent_age          22725 non-null  float64
#  8   sex                     22725 non-null  object
#  9   the_relathip_with_head  22725 non-null  object
#  10  marital_status          22725 non-null  object
#  11  level_of_educuation     22725 non-null  object
#  12  type_of_job             22725 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 2.3+ MB

# %%
# Plotting bar graphs to show the relationships between different variable
fig,ax1 =plt.subplots(figsize=(4,4))
graph = sns.countplot(ax=ax1, x='sex',hue='has_a_bank_account',data=financial_df)
graph.set_xticklabels(graph.get_xticklabels())
for p in ax.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1, height , ha='center')
sns.catplot(x='sex', col='has_a_bank_account', data=financial_df, kind='count', height=4, aspect=.7)

# %% [markdown]
# More Female have bank accounts compared to the male population

# %%
# Bar graph to analyze countries as per the number of people with bank accounts
fig,ax1 =plt.subplots(figsize=(5,5))
graph = sns.countplot(ax=ax1, x='country',hue='has_a_bank_account',data=financial_df, palette='rainbow')
graph.set_xticklabels(graph.get_xticklabels())
for p in graph.patches:
    height = p.get_x() + p.get_width()
    height= p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1, height , ha='center')

# %% [markdown]
# Rwanda has the highest population with bank accounts

# %%
# Bar graph to analyze the level of education as per the number of people with bank accounts
fig,ax1 =plt.subplots(figsize=(30,15))
graph = sns.countplot(ax=ax1, x='level_of_educuation',hue='has_a_bank_account',data=financial_df, palette='rainbow')
graph.set_xticklabels(graph.get_xticklabels())
for p in graph.patches:
    height = p.get_x() + p.get_width()
    height= p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1, height , ha='center')
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# Bar graph to analyze people's marital status as per the number of people with bank accounts
fig,ax1 =plt.subplots(figsize=(30,15))
graph = sns.countplot(ax=ax1, x='marital_status',hue='has_a_bank_account',data=financial_df, palette='rainbow')
graph.set_xticklabels(graph.get_xticklabels())
for p in graph.patches:
    height = p.get_x() + p.get_width()
    height= p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1, height , ha='center')

# %%
financial_df.boxplot(column='respondent_age', by='has_a_bank_account')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
financial_df.boxplot(column='household_size', by='has_a_bank_account')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Continous Variable and Continous Variable

# %%
sns.scatterplot(x=financial_df['respondent_age'], y=financial_df['household_size'])

# %%
sns.jointplot(x='respondent_age', y='household_size', data=financial_df)

# %%
# Calculating the pearson coefficient
financial_df["respondent_age"].corr(financial_df["household_size"])
# Out:
# -0.1062088216975987

# %% [markdown]
# This shows that there is a weak negative correlation between respondent age and household size.

# %% [markdown]
# ##8. Multivariate Analysis

# %%
fig, ax1 = plt.subplots(figsize=(8,5))
plot=sns.boxplot(ax=ax1, x='country',y='respondent_age', hue='sex', data=financial_df)

# %%
sns.catplot(data=financial_df, col = "has_a_bank_account", x='sex', hue='country', kind='count')

# %%
fig,ax=plt.subplots(figsize = (10,6))
corr=financial_df.corr()
sns.heatmap(corr, annot=True)

# %%
sns.pairplot(financial_df)

# %% [markdown]
# ####Principal Component Analysis

# %%
# Step 1: We will start by loading our dataset
financial_df.head()
# Out:
#   country  year  uniqueid has_a_bank_account type_of_location  \
# 0   Kenya  2018         1                Yes            Rural
# 1   Kenya  2018         2                 No            Rural
# 2   Kenya  2018         3                Yes            Urban
# 3   Kenya  2018         4                 No            Rural
# 4   Kenya  2018         5                 No            Urban
#
#   cell_phone_access  household_size  respondent_age     sex  \
# 0               Yes               3            24.0  Female
# 1                No               5            70.0  Female
# 2               Yes               5            26.0    Male
# 3               Yes               5            34.0  Female
# 4                No               8            26.0    Male
#
#   the_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# 2         Other relative     Single/Never Married
# ...

# %%
dummy=pd.get_dummies(financial_df['has_a_bank_account'])
dummy
# Out:
#        No  Yes
# 0       0    1
# 1       1    0
# 2       0    1
# 3       1    0
# 4       1    0
# ...    ..  ...
# 22720   1    0
# 22721   1    0
# 22722   1    0
# 22723   1    0
# 22724   1    0
#
# [22725 rows x 2 columns]

# %%
df=pd.concat((financial_df,dummy), axis=1)
df.head()
# Out:
#   country  year  uniqueid has_a_bank_account type_of_location  \
# 0   Kenya  2018         1                Yes            Rural
# 1   Kenya  2018         2                 No            Rural
# 2   Kenya  2018         3                Yes            Urban
# 3   Kenya  2018         4                 No            Rural
# 4   Kenya  2018         5                 No            Urban
#
#   cell_phone_access  household_size  respondent_age     sex  \
# 0               Yes               3            24.0  Female
# 1                No               5            70.0  Female
# 2               Yes               5            26.0    Male
# 3               Yes               5            34.0  Female
# 4                No               8            26.0    Male
#
#   the_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# 2         Other relative     Single/Never Married
# ...

# %%
df=df.drop(['has_a_bank_account'], axis=1)
df.head()
# Out:
#   country  year  uniqueid type_of_location cell_phone_access  household_size  \
# 0   Kenya  2018         1            Rural               Yes               3
# 1   Kenya  2018         2            Rural                No               5
# 2   Kenya  2018         3            Urban               Yes               5
# 3   Kenya  2018         4            Rural               Yes               5
# 4   Kenya  2018         5            Urban                No               8
#
#    respondent_age     sex the_relathip_with_head           marital_status  \
# 0            24.0  Female                 Spouse  Married/Living together
# 1            70.0  Female      Head of Household                  Widowed
# 2            26.0    Male         Other relative     Single/Never Married
# 3            34.0  Female      Head of Household  Married/Living together
# 4            26.0    Male                  Child     Single/Never Married
#
# ...

# %%
df=df.drop(['No'], axis=1)
df.head()
# Out:
#   country  year  uniqueid type_of_location cell_phone_access  household_size  \
# 0   Kenya  2018         1            Rural               Yes               3
# 1   Kenya  2018         2            Rural                No               5
# 2   Kenya  2018         3            Urban               Yes               5
# 3   Kenya  2018         4            Rural               Yes               5
# 4   Kenya  2018         5            Urban                No               8
#
#    respondent_age     sex the_relathip_with_head           marital_status  \
# 0            24.0  Female                 Spouse  Married/Living together
# 1            70.0  Female      Head of Household                  Widowed
# 2            26.0    Male         Other relative     Single/Never Married
# 3            34.0  Female      Head of Household  Married/Living together
# 4            26.0    Male                  Child     Single/Never Married
#
# ...

# %%
df=df.rename(columns={'Yes':'has_a_bank_account'})
df.head()
# Out:
#   country  year  uniqueid type_of_location cell_phone_access  household_size  \
# 0   Kenya  2018         1            Rural               Yes               3
# 1   Kenya  2018         2            Rural                No               5
# 2   Kenya  2018         3            Urban               Yes               5
# 3   Kenya  2018         4            Rural               Yes               5
# 4   Kenya  2018         5            Urban                No               8
#
#    respondent_age     sex the_relathip_with_head           marital_status  \
# 0            24.0  Female                 Spouse  Married/Living together
# 1            70.0  Female      Head of Household                  Widowed
# 2            26.0    Male         Other relative     Single/Never Married
# 3            34.0  Female      Head of Household  Married/Living together
# 4            26.0    Male                  Child     Single/Never Married
#
# ...

# %%
# We will drop the Categorical Data since they cannot be used in doing PCA
df=df.select_dtypes(['number']) 
df.head()
# Out:
#    year  uniqueid  household_size  respondent_age  has_a_bank_account
# 0  2018         1               3            24.0                   1
# 1  2018         2               5            70.0                   0
# 2  2018         3               5            26.0                   1
# 3  2018         4               5            34.0                   0
# 4  2018         5               8            26.0                   0

# %%
# Step 2: Preprocessing
# The first preprocessing step is to divide the dataset into a feature set and corresponding labels. 
# The following script performs this task. The script below stores the feature sets into the X variable 
# and the series of corresponding labels in to the y variable.
# 
X = df.drop('has_a_bank_account', 1)
y = df['has_a_bank_account']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
# Step 3: Splitting the dataset into the Training set and Test set
# The next preprocessing step is to divide data into training and test sets. 
# We execute the following script to do so:
#
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Step 4: Normalization
# As mentioned earlier, PCA performs best with a normalized feature set. 
# We will perform standard scalar normalization to normalize our feature set. 
# To do this, we execute the following code:
# 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Step 5: Applying PCA
# It is only a matter of three lines of code to perform PCA using Python's Scikit-Learn library. 
# The PCA class is used for this purpose. PCA depends only upon the feature set and not the label data. 
# Therefore, PCA can be considered as an unsupervised machine learning technique.
# Performing PCA using Scikit-Learn is a two-step process:
# Initialize the PCA class by passing the number of components to the constructor.
# Call the fit and then transform methods by passing the feature set to these methods. 
# The transform method returns the specified number of principal components.
# Let's take a look at the following code. In the code above, we create a PCA object named pca. 
# We did not specify the number of components in the constructor. 
# Hence, all four of the features in the feature set will be returned for both the training and test sets.
# 
from sklearn.decomposition import PCA

pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Step 7: Explained Variance Ratio
# The PCA class contains explained_variance_ratio_ which returns the variance caused by each of the principal components. 
# We execute the following line of code to find the "explained variance ratio".
# 
explained_variance = pca.explained_variance_ratio_

# The explained_variance variable is now a float type array which contains variance ratios for each principal component. 
# The values for the explained_variance variable looks like what is shown in the output. 
# It can be seen that first principal component is responsible for 72.22% variance. 
# Similarly, the second principal component causes 23.9% variance in the dataset. 
# Collectively we can say that (72.22 + 23.9) 96.21% percent of the classification information contained 
# in the feature set is captured by the first two principal components.
explained_variance
# Out:
# array([0.34051888, 0.2755474 , 0.22041805, 0.16351566])

# %%
# Step 8: Using 1 Principal Component
# Let's first try to use 1 principal component to train our algorithm. To do so, execute the following code:
# 
from sklearn.decomposition import PCA

pca = PCA(n_components=1)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Step 9: Training and Making Predictions
# In this case we'll use random forest classification for making the predictions.
# 
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Step 10: Performance Evaluation
# 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy' , accuracy_score(y_test, y_pred))

# Noting that from the output that with only one feature, 
# the random forest algorithm is able to correctly predict 28 out of 30 instances, 
# resulting in 85.72% accuracy.
# Out:
# [[3896    0]
#  [ 649    0]]
# Accuracy 0.8572057205720572

# %% [markdown]
# #7. Implementing the Solution
# To implement my solution, I carried out Univariate, Bivariate, and Multivariate Analysis to see the relatioship of the different variables which play a great role in people having bank accounts.

# %% [markdown]
# #8. Challenging the Solution

# %% [markdown]
# #9. Follow up Questions
# 1. What are the factors affecting most people from having bank accounts?
# 2. What best strategies can be implemented to reach out to the people who do not have banks accounts, since they accupy the greates percentage in our Analysis.
